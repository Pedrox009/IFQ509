# %%
import pandas as pd
import numpy as np
df = pd.read_csv("Dataset.csv")
print(df.head())
# Out:
#    Participant_ID survey_date region country  ip_latitude  ip_longitude  \
# 0       862217754  02/12/2020      ?      US      42.3690      -88.0651
# 1         2363592  02/07/2020     AF      ZA     -26.2870       28.2427
# 2         2570172  05/07/2020     AF      ZA     -26.2019       28.0273
# 3         2812446  13/06/2020     AF      ZA     -33.8268       18.4772
# 4         2867850  29/06/2020     AF      ZA     -26.3120       28.1024
#
#    gender    age  height  weight  ...  heart_disease lung_disease diabetes  \
# 0    male  30_40     180      98  ...              0            0        0
# 1    male  30_40     168      66  ...              0            0        1
# 2  female  60_70     172      86  ...              0            0        0
# 3    male  40_50     172     140  ...              1            0        1
# 4    male  20_30     186      78  ...              0            0        0
#
#   hiv_positive other_chronic  nursing_home  health_worker  risk_infection  \
# 0            0             0             0              0           100.0
# 1            0             0             0              0            75.0
# 2            0             0             0              0             5.0
# 3            0             0             0              0           100.0
# 4            0             0             0              0             5.0
#
#    risk_infection_level risk_mortality
# 0                  high          0.063
# 1              moderate          0.098
# 2                   low          0.582
# 3                  high          1.032
# 4                   low          0.050
#
# [5 rows x 38 columns]

# %%
df.info()
df.isna().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5789 entries, 0 to 5788
# Data columns (total 38 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Participant_ID          5789 non-null   int64
#  1   survey_date             5789 non-null   str
#  2   region                  5774 non-null   str
#  3   country                 5786 non-null   str
#  4   ip_latitude             5789 non-null   float64
#  5   ip_longitude            5789 non-null   float64
#  6   gender                  5789 non-null   str
#  7   age                     5789 non-null   str
#  8   height                  5789 non-null   int64
#  9   weight                  5789 non-null   int64
#  10  bmi                     5789 non-null   float64
#  11  blood_type              5689 non-null   str
#  12  insurance               4497 non-null   str
#  13  income                  4636 non-null   str
#  14  smoking                 5753 non-null   str
#  15  alcohol                 5789 non-null   float64
#  16  cocaine                 1430 non-null   float64
#  17  contacts_count          5747 non-null   float64
#  18  public_transport_count  4572 non-null   float64
#  19  working                 5761 non-null   str
#  20  worried                 4518 non-null   float64
#  21  covid19_positive        5789 non-null   int64
#  22  covid19_symptoms        5789 non-null   int64
#  23  covid19_contact         5789 non-null   int64
#  24  asthma                  5789 non-null   int64
#  25  kidney_disease          5789 non-null   int64
#  26  liver_disease           5789 non-null   int64
#  27  compromised_immune      5789 non-null   int64
#  28  heart_disease           5789 non-null   int64
#  29  lung_disease            5789 non-null   int64
#  30  diabetes                5789 non-null   int64
#  31  hiv_positive            5789 non-null   int64
#  32  other_chronic           5789 non-null   int64
#  33  nursing_home            5789 non-null   int64
#  34  health_worker           5789 non-null   int64
#  35  risk_infection          5789 non-null   float64
#  36  risk_infection_level    5789 non-null   str
#  37  risk_mortality          5789 non-null   float64
# dtypes: float64(10), int64(17), str(11)
# memory usage: 1.7 MB
# Participant_ID               0
# survey_date                  0
# region                      15
# country                      3
# ip_latitude                  0
# ip_longitude                 0
# gender                       0
# age                          0
# height                       0
# weight                       0
# bmi                          0
# blood_type                 100
# insurance                 1292
# income                    1153
# smoking                     36
# alcohol                      0
# cocaine                   4359
# contacts_count              42
# public_transport_count    1217
# working                     28
# worried                   1271
# covid19_positive             0
# covid19_symptoms             0
# covid19_contact              0
# asthma                       0
# kidney_disease               0
# liver_disease                0
# compromised_immune           0
# heart_disease                0
# lung_disease                 0
# diabetes                     0
# hiv_positive                 0
# other_chronic                0
# nursing_home                 0
# health_worker                0
# risk_infection               0
# risk_infection_level         0
# risk_mortality               0
# dtype: int64

# %% [markdown]
# We have 5789 rows and have identified:
# - "region", "country", "blood_type", "insurance", "income", "smoking", "cocaine", "contacts_count", "public_transport_count", "working", and "worried" variables contain null values

# %%
#look at rows with issues
for column in df.select_dtypes(exclude="number").columns:
    print(column)
    print(df[column].unique())
    print()
# Out:
# survey_date
# <StringArray>
# ['02/12/2020', '02/07/2020', '05/07/2020', '13/06/2020', '29/06/2020',
#  '04/07/2020', '07/07/2020', '22/05/2020', '06/04/2020', '21/05/2020',
#  ...
#  '20/04/2020', '24/04/2020', '01/05/2020', '22/04/2020', '05/05/2020',
#  '03/05/2020', '11/05/2020', '25/03/2020', '26/03/2020', '24/03/2020']
# Length: 120, dtype: str
#
# region
# <StringArray>
# ['?', 'AF', 'AS', 'EU', nan, 'N-A', 'OC', 'SA']
# Length: 8, dtype: str
#
# country
# <StringArray>
# ['US', 'ZA', 'MZ', 'EG', 'IN', 'IL', 'JP', 'KZ', 'ID', 'PH', 'HK', 'IQ', 'IR',
#  'AZ', 'MO', 'PK', 'MY', 'SA', 'GB', 'MK', 'PT', 'NO', 'IE', 'NL', 'DE', 'FR',
#  'IT', 'BE', 'CZ', 'GR', 'SE', 'SI', 'FI', 'BA', 'ES', 'HU', 'HR', 'JE', 'RO',
#  'RU', 'BG', 'CA', 'GT', 'MX', 'KY', 'BS', 'NZ', 'AU', 'BR', 'CL', 'AR', 'CO',
#  'PE', 'MA', 'AE', 'BD', 'QA', 'TR', 'BH', 'GE', 'AT', 'PL', 'CH', 'MD', 'AD',
#  'RS', 'SK', 'MT', 'DK', 'DO', 'BM', 'PA', 'HN', 'PR', 'CR', 'EC',  nan, 'MU',
#  'KE', 'TH', 'SG', 'NP', 'AM', 'LU', 'LT', 'UA', 'VI', 'DZ', 'ET', 'KR', 'PS',
#  'MM', 'AW', 'LV', 'SV']
# Length: 95, dtype: str
#
# gender
# <StringArray>
# ['male', 'female', 'other']
# Length: 3, dtype: str
#
# age
# <StringArray>
# [  '30_40',   '60_70',   '40_50',   '20_30',   '50_60',   '10_20',    '0_10',
#    '70_80', '100_110']
# Length: 9, dtype: str
#
# blood_type
# <StringArray>
# ['unknown', 'bp', 'ap', 'op', 'on', 'abp', 'bn', 'an', 'abn', nan]
# Length: 10, dtype: str
#
# insurance
# <StringArray>
# [nan, 'yes', 'no', 'blank']
# Length: 4, dtype: str
#
# income
# <StringArray>
# [nan, 'med', 'high', 'low', 'blank', 'gov']
# Length: 6, dtype: str
#
# smoking
# <StringArray>
# [    'never',    'quit10',     'quit0',  'yeslight',      'vape', 'yesmedium',
#      'quit5',  'yesheavy',         nan]
# Length: 9, dtype: str
#
# working
# <StringArray>
# ['home', 'never', 'stopped', 'travel critical', 'travel non critical', '?',
#  nan]
# Length: 7, dtype: str
#
# risk_infection_level
# <StringArray>
# ['high', 'moderate', 'low']
# Length: 3, dtype: str

# %% [markdown]
# We must decide if we wish to delete or replace these values

# %%
#replace NaN and ? values with Unkown
df["region"] = df["region"].replace("?",pd.NA)
df["region"].isna().sum()
# Out:
# np.int64(27)

# %% [markdown]
# After data is cleaned, proceed below

# %%
#average contacts_count of a patient from the US who is COVID-19 positive
df[(df["country"] == "US") & (df["covid19_positive"] == 1)]["contacts_count"].mean()
# Out:
# np.float64(8.24438902743142)

# %%
#covid 19 positive counts per country
df[df["covid19_positive"] == 1]["country"].value_counts()
# Out:
# country
# US    1627
# BR     164
# GB     132
# CA      61
# MX      40
#       ...
# ET       1
# PS       1
# CZ       1
# TH       1
# PA       1
# Name: count, Length: 73, dtype: int64

# %%
#number heakth workers
df["health_worker"].sum()
# Out:
# np.int64(490)

# %%
#health worker and covid positive
df[(df["health_worker"] == 1) & (df["covid19_positive"] == 1)].shape[0] #shape[0] means number of rows
# Out:
# 182

# %%
#average mortality risk per country (top 5)
df.groupby("country")["risk_mortality"].mean().sort_values(ascending=False)
# Out:
# country
# AD    3.994000
# BS    2.273000
# AW    2.171000
# AM    1.923500
# IR    1.787500
#         ...
# BH    0.062500
# FI    0.056333
# MT    0.050000
# KE    0.050000
# JE    0.050000
# Name: risk_mortality, Length: 94, dtype: float64
